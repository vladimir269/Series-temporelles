# %% [markdown]
# # Projet Série Temporelles
# *AHOUMENOU Onel, DEVIGNAC Vladimir, DURAND Arnaud*

# %% [markdown]
# ## Packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#!pip install scikit-learn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %% [markdown]
# ## Introduction

# %% [markdown]
# Dans ce projet, nous allons illustrer sur un jeu de données concret les méthodes étudiées au cours. Nos données proviennent du site kaggle https://www.kaggle.com/datasets/aminesnoussi/air-pollution-dataset. Il traite de la pollution de l'air à Pekin.
#
#   L'objectif est donc de prédire la pollution futur à l'aide des données passées en suivant le plan suivant:

# %% [markdown]
# 1. [Pré-traitement des données](#partie1)
# 2. [Gestion de la non-stationnarité](#partie2)
# 3. [Identification de modèle(s) probabiliste(s)](#partie3)
# 4. [Estimation des paramètres du(des) modèle(s)](#partie4)
# 5. [Prédiction des valeurs futures](#partie5)
# 6. [Evaluation de la précision de prédiction](#partie6)

# %% [markdown]
# ## Pré-traitement des données <a id="partie1"></a>

# %% [markdown]
# ### Analyse de la base de données

# %%
# Importation des données

data = pd.read_csv("air_pollution.csv", index_col='date', parse_dates=True)
data.head()
# Out:
#             pollution_today        dew       temp        press     wnd_spd  \
# date
# 2010-01-02       145.958333  -8.500000  -5.125000  1024.750000   24.860000
# 2010-01-03        78.833333 -10.125000  -8.541667  1022.791667   70.937917
# 2010-01-04        31.333333 -20.875000 -11.500000  1029.291667  111.160833
# 2010-01-05        42.458333 -24.583333 -14.458333  1033.625000   56.920000
# 2010-01-06        56.416667 -23.708333 -12.541667  1033.750000   18.511667
#
#                  snow  rain  pollution_yesterday
# date
# 2010-01-02   0.708333   0.0            10.041667
# 2010-01-03  14.166667   0.0           145.958333
# 2010-01-04   0.000000   0.0            78.833333
# 2010-01-05   0.000000   0.0            31.333333
# 2010-01-06   0.000000   0.0            42.458333

# %% [markdown]
# ### Isolation de la variable cible "pollution_today"

# %%
pollution_today = data['pollution_today']

# %%
# Affichage de la série temporelle

moyennes_mensuelles = pollution_today.resample('M').mean()

plt.figure(figsize=(18, 5))

pollution_today.plot()
moyennes_mensuelles.plot(label="moyennes_mensuelles", lw=2, c='red')

plt.legend()
plt.title("Pollution de l'air à Pekin entre 2010 et 2013")
plt.show()

# %%
# Moyennes mensuelles par années de la série temporelle

mois = ['Janvier', 'Février', 'Mars', 'Avril', 'Mai', 'Juin', 'Juillet', 'Aout', 'Septembre', 'Octobre', 'Novembre', 'Décembre']
années = ['2010', '2011', '2012', '2013', '2014']
sep = 'M'

plt.figure(figsize=(15, 5))
for an in années:
    plt.plot(mois, pollution_today[an].resample(sep).mean(), label=an)
plt.legend()
plt.title("Moyenne mensuelle par années")
plt.show()

# %%
# Informations utiles

pollution_today.describe()
# Out:
# count    1825.000000
# mean       98.245080
# std        76.807697
# min         3.166667
# 25%        42.333333
# 50%        79.166667
# 75%       131.166667
# max       541.895833
# Name: pollution_today, dtype: float64

# %%
# Nombre de valeurs manquantes

pollution_today.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Gestion de la non-stationnarité <a id="partie2"></a>

# %%
X = pd.DataFrame(np.array([i for i in range(len(data['pollution_today'].resample('M').mean()))]), index=data.resample('M').mean().index, columns=['X'])

X_train = X['X']['2010':'2013']
X_test = X['X']['2014':]

y_train = data['pollution_today']['2010':'2013'].resample('M').mean()
y_test = data['pollution_today']['2014':].resample('M').mean()

pollution = y_train

# %%
pollution.plot(figsize=(18, 5))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Isolation de la tendance

# %% [markdown]
# Nous allons isoler la tendance à l'aide d'une moyenne mobile d'ordre 12 (pour 12 mois par an)

# %%
p = 12  # période

tendance_isolee = pollution.rolling(window=p, min_periods=4, closed='both', center=True).mean()

plt.figure(figsize=(18, 5))
tendance_isolee.plot()
plt.show()

# %%
tendance_isolee.isna().sum()
# Out:
# 0

# %% [markdown]
# ### Estimation de la saisonnalité

# %% [markdown]
# A l'aide de la tendance obtenue précédemment, nous allons determiner la série corrigée de la tendance, notée ici **serie_corrigee_tendance**, puis calculer les coefficients de saisonnalité.

# %%
# Saisonnalité

serie_corrigee_tendance = pollution - tendance_isolee
saisonnalite = [np.mean([serie_corrigee_tendance[j] for j in range(0, len(pollution)) if j%p == i]) for i in range(p)]

moy = np.mean(saisonnalite)
for i in range(len(saisonnalite)):
    saisonnalite[i] = saisonnalite[i] - moy
saisonnalite #sum(saisonnalite)
# Out:
# [12.227636928567506,
#  15.038762504327993,
#  -2.91640601453982,
#  -17.33243780681384,
#  -16.337580970506227,
#  7.536436166310803,
#  -3.4314282054472165,
#  -13.648256597848954,
#  -12.893168928801108,
#  17.27407957576872,
#  8.400856847120922,
#  6.081506501861226]

# %%
rep_saisonnalite = []

rep_n = 0
while len(rep_saisonnalite) != len(pollution):
    rep_saisonnalite.append(saisonnalite[rep_n%p])
    rep_n += 1

df_saisonnalite = pd.DataFrame(rep_saisonnalite, index = pollution.index, columns=["saisonnalite"])
df_saisonnalite["saisonnalite"].plot(figsize=(18, 5))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Estimation de la tendance

# %%
tendance = pollution - rep_saisonnalite

df_tendance = pd.DataFrame(np.array(tendance), index = pollution.index, columns=["tendance"])
df_tendance["tendance"].plot(figsize=(18, 5))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Modelisation de la tendance

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)

X_train.shape = (len((X_train)), 1)
y_train.shape = (len((y_train)), 1)

X_test = np.array(X_test)
y_test = np.array(y_test)

X_test.shape = (len((X_test)), 1)
y_test.shape = (len((y_test)), 1)

# %%
modele_tendance = LinearRegression()
modele_tendance.fit(X_train, y_train)
predictions = modele_tendance.predict(X_test)

# %%
predictions_finales = np.array([predictions[i][0] + saisonnalite[i] for i in range(len(saisonnalite))])
predictions_finales.shape = (len((predictions_finales)), 1)
predictions_finales
# Out:
# array([[108.59772309],
#        [111.32568002],
#        [ 93.28734285],
#        [ 78.78814242],
#        [ 79.69983061],
#        [103.4906791 ],
#        [ 92.43964608],
#        [ 82.13964905],
#        [ 82.81156807],
#        [112.89564793],
#        [103.93925656],
#        [101.53673757]])

# %%
y_test
# Out:
# array([[117.96505376],
#        [174.66517857],
#        [110.36895161],
#        [ 95.54236111],
#        [ 72.10752688],
#        [ 58.73402778],
#        [ 88.71505376],
#        [ 63.26344086],
#        [ 70.12916667],
#        [140.69758065],
#        [107.925     ],
#        [ 80.79973118]])

# %%
# Erreur quadratique RMSE

np.sqrt(np.sum((predictions_finales - y_test)**2)/len((y_test)))
# Out:
# 26.587605590151284

# %%
plt.figure(figsize=(15, 5))
plt.scatter([i for i in range(len(y_train))], y_train)
plt.plot(y_train)
plt.plot(modele_tendance.predict(X_train))
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot(data['2010':'2013'].resample('M').mean().index, y_train)
plt.plot(data['2014':].resample('M').mean().index, predictions_finales)
plt.title("Prédictions")
plt.show()

# %%
data['pollution_today'].resample('M').mean().plot(figsize=(15, 5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
plot_acf(data['pollution_today'])

# %%
plot_pacf(data['pollution_today'], method='ywm')
